# %% [markdown]
# # 04 — Evaluación del modelo REM (GNN + GMRES matrix-free)
#
# > ⏳ **Pendiente de implementar** (TAREA 5, tras TAREA 4).
# > ⚠️ Prerrequisito: dataset REM de circuitos triviales con SOLO ruido de lectura (sub-ítem TAREA 4) — aún no existe.
#
# **Qué hará este notebook:**
# 1. Métricas del REM (Hellinger Fidelity, TVD, ratio de mejora HF_mit/HF_noisy) con los mismos splits que el 03.
# 2. Evaluación del solver GMRES en el subespacio de bitstrings observados (nunca la matriz 2^n × 2^n completa).
# 3. Comparativa empírica de memoria: enfoque clásico O(2^{3n}) vs. subespacio O(N).
