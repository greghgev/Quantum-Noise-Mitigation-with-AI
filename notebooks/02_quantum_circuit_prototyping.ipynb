# %% [markdown]
# # 02 — Tipos de circuito y estudio del shot noise
#
# > ⏳ **Pendiente de implementar** (TAREA 5, tras TAREA 4). Plan detallado en `doc/notebooks_info.md`.
#
# **Qué hará este notebook:**
# 1. Los 5 tipos de circuito (random, HEA, TFIM, QAOA, QFT) lado a lado: estructura, profundidad tras transpilar a base Heron, distribución de salida ideal vs. ruidosa.
# 2. **Barrido de shots (1024 → 16384)** midiendo la estabilidad de la etiqueta Δ por tipo — la justificación empírica del valor de `LABEL_SHOTS` (responde al suelo de shot-noise detectado en TAREA 8).
# 3. Distinción `LABEL_SHOTS` (etiquetas limpias) vs. `TRAIN_SHOTS` (inputs REM realistas).
