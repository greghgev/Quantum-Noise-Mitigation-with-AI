# %% [markdown]
# # 03 — Entrenamiento y evaluación del GEM (Graph Transformer)
#
# > ⏳ **Pendiente de implementar** (TAREA 5, tras TAREA 4). Alcance revisado jul-2026: Δ es el error TOTAL (puertas + readout) — sin prerrequisitos de regeneración.
#
# **Qué hará este notebook:**
# 1. Entrenamiento del Graph Transformer (nodo QCR, sin message-passing) sobre el dataset de grafos.
# 2. Métricas (MAE, RMSE, R², mejora relativa) separadas por: in-distribution / zero-shot QAOA / zero-shot QFT / por día del split temporal.
# 3. Curvas de aprendizaje, análisis de residuos y test de estrés por profundidad (5→50 capas).
