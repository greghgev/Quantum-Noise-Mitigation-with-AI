# %% [markdown]
# # 03 — Evaluación del modelo GEM (Graph Transformer)
#
# > ⏳ **Pendiente de implementar** (TAREA 5, tras TAREA 4).
# > ⚠️ Prerrequisito: etiquetas Δ regeneradas con readout DESACTIVADO (sub-ítem TAREA 4) — el dataset actual mezcla ruido de puertas y de lectura.
#
# **Qué hará este notebook:**
# 1. Métricas del GEM (MAE, RMSE, R², mejora relativa) separadas por: in-distribution / zero-shot QAOA / zero-shot QFT / por día del split temporal.
# 2. Curvas de aprendizaje y análisis de residuos de la predicción de Δ.
# 3. Test de estrés por profundidad (5→50 capas) para localizar el punto de colapso del modelo.
