# %% [markdown]
# # 04 — Comparativa de modelos: Ridge vs. Random Forest vs. GEM
#
# > ⏳ **Pendiente de implementar** (TAREA 5). **Es el núcleo del TFM revisado** (jul-2026, acordado con el tutor).
# > Sustituye al antiguo notebook de evaluación REM, que pasa a trabajo futuro (`IDEAS_FUTURAS.md`, IDEA-0).
#
# **Qué hará este notebook:**
# 1. Los 3 modelos prediciendo el mismo Δ: Ridge y Random Forest sobre features agregadas (`src/features.py`), GEM sobre el grafo completo.
# 2. Protocolo IDÉNTICO: mismos splits, mismas métricas, misma semilla — la comparación es el resultado, no la excelencia de un modelo.
# 3. Tabla comparativa por split + análisis de dónde gana cada modelo (¿aporta el grafo frente a las features agregadas?).
