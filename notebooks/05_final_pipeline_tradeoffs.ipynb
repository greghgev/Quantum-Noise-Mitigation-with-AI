# %% [markdown]
# # 05 — Pipeline completo y análisis de trade-offs
#
# > ⏳ **Pendiente de implementar** (TAREA 5, el último).
# > Requiere proporciones random/estructurados configurables en `generate_dataset()` (sub-ítem TAREA 4).
#
# **Qué hará este notebook:**
# 1. El flujo de inferencia completo: circuito → GEM predice Δ → simulación con ruido total → REM limpia el histograma → ajuste final ⟨O⟩ = ruidoso − Δ.
# 2. Ablación de la composición del dataset: 70/30 vs. 80/20 vs. 90/10 (random/estructurados).
# 3. Trade-offs (fidelidad vs. latencia vs. coste) con barras agrupadas / small multiples, y exportación de figuras finales para la memoria.
