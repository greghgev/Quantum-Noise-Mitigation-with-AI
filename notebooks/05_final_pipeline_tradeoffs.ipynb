# %% [markdown]
# # 05 — Análisis final y trade-offs
#
# > ⏳ **Pendiente de implementar** (TAREA 5, el último). Alcance revisado jul-2026 (solo GEM).
#
# **Qué hará este notebook:**
# 1. El mejor modelo de la comparativa aplicado al flujo completo: circuito → predicción de Δ → corrección ⟨O⟩ = ruidoso − Δ.
# 2. Ablación de la composición del dataset 70/30 vs. 80/20 vs. 90/10 (opcional si hay tiempo).
# 3. Trade-offs (precisión vs. coste de entrenamiento vs. latencia) con barras agrupadas, y exportación de figuras/tablas para la memoria.
